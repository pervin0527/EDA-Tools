# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import norm

# %%
# 한글 폰트 설정
plt.rc('font', family='NanumGothic')  # 나눔고딕 폰트 사용
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
df = pd.read_excel("./data/SR_ROW.xlsx", sheet_name="308명")

# %%
df.head()
# Out:
#       id name dept_name  job position                    email   직위  근속년수  \
# 0  834.0  하세용     인재경영처   부원       6급    seyong.ha@srail.or.kr   주임  0.67
# 1  784.0  김현은     고객홍보처   부원       6급      he1.kim@srail.or.kr   주임  3.24
# 2  812.0  정지원     재무계약처   부원       5급     jw.jeong@srail.or.kr   대리  6.23
# 3  897.0  한주빈     수서관리역  역무원       6급    jubin.han@srail.or.kr  역무원  0.67
# 4  891.0  김진선     수서관리역  역무원       6급  jinseon.kim@srail.or.kr  역무원  1.94
#
#      연령  성별  ... 직관형(WORK_INTUITION) 성취형(WORK_AHCIEVE) 전문가형(WORK_SPECIAL)  \
# 0  20.0  남성  ...                4.55              2.86               1.47
# 1  20.0  여성  ...                4.55              2.86               0.88
# 2  20.0  여성  ...                1.36              1.79               3.53
# 3  20.0  여성  ...                2.27              3.21               2.06
# 4  20.0  여성  ...                3.18              2.50               2.65
#
#   논리형(WORK_DATADRIVEN)  일중심사고형(WORK_WORKERHOLIC)  협력형(WORK_COWORK)  \
# 0                 2.22                      3.82              2.69
# 1                 2.22                      2.35              3.08
# 2                 3.33                      3.24              2.69
# 3                 3.33                      2.94              3.46
# 4                 3.33                      2.35              2.69
#
#    과정주의형(WORK_PROCESS)  몰입형(WORK_ABSORB)  마당발형(WORK_POPULAR)  모사형(WORK_RELATE)
# 0                 1.00              2.33                 2.0               2.0
# 1                 2.25              2.33                 4.0               1.5
# 2                 1.25              3.33                 2.0               2.5
# 3                 2.50              2.33                 4.0               1.5
# 4                 3.00              4.00                 2.0               2.5
#
# [5 rows x 95 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'dept_name', 'job', 'position', 'email', '직위', '근속년수',
#        '연령', '성별', '인사하위', '본사/현업', '사원하위그룹', '권한', '자신감(SEO_C)', '신중함(SEO_D)',
#        '수평적(SEO_H)', '개인중심(SEO_I)', '직관(SEO_N)', '시스템중심(SEO_O)', '과정주의(SEO_P)',
#        '분석(SEO_S)', '결과주의(SEO_U)', '수직적(SEO_V)', '역할중심형(AIR_B)', '신중형(AIR_D)',
#        '주도형(AIR_L)', '조직중심사고(TC_C)', '몰입형(AIR_H)', '수평소통(TC_H)',
#        '개인중심사고(TC_I)', '위계소통(TC_V)', '주인의식형(AIR_O)', '촉진형(AIR_F)',
#        '창조(VISION_CREATIVITY)', '혁신(VISION_INNOVATION)', '열정(VISION_PASSION)',
#        '인재(VISION_TALENT)', '성장(VISION_GROWTH)', '신속성(VISION_QUICK)',
#        '도전(VISION_CHALLENGE)', '문제해결(VISION_SOLVING)', '전문성(VISION_SPECIAL)',
#        '고객(VISION_CUSTOMER)', '상생(VISION_COEXISTENCE)',
#        '소통(VISION_COMMUNICATION)', '최고지향(VISION_BEST)',
#        '성과(VISION_PERFORMANCE)', '사회공헌(VISION_CONTRIBUTION)',
#        '즐거움(VISION_FUN)', '직무내용(TURNOVER_JOB)', '발전가능(TURNOVER_GROWTH)',
#        '근로시간(TURNOVER_HOUR)', '근무환경(TURNOVER_OFFICE)', '취업안정(TURNOVER_SAFETY)',
#        '급여만족(TURNOVER_SALARY)', '복리후생(TURNOVER_WELFARE)',
#        '공정인사(TURNOVER_FAIRNESS)', '소통관계(TURNOVER_RELATION)',
#        '목표지향형(WORK_GOAL)', '혁신형(WORK_INNOVATE)', '도전형(WORK_CHALLENGE)',
#        '역할중심형(WORK_RULEBASE)', '오만형(WORK_LEAD)', '솔선수범형(WORK_INITIATIVE)',
#        '자기확신형(WORK_CONFIDENCE)', '유니크형(WORK_UNIQUE)', '부정형(WORK_DEFENCE)',
#        '책임형(WORK_RESPONSE)', '투쟁형(WORK_STRUGGLE)', '스피드형(WORK_SPEED)',
#        '창조형(WORK_CREAT)', '윤리형(WORK_HONEST)', '열정형(WORK_PASSION)',
#        '조력자형(WORK_HELP)', '긍정형(WORK_POSITIVE)', '신뢰형(WORK_TRUST)',
#        '끈기형(WORK_ENDURANCE)', '과몰입형(WORK_PRIDE)', '스마트형(WORK_SMART)',
#        '방관형(WORK_LIMIT)', '분석형(WORK_ANALYSIS)', '열린사고형(WORK_OPEN)',
#        '겸손형(WORK_MODESTY)', '촉진자형(WORK_FACILITATE)', '직관형(WORK_INTUITION)',
#        '성취형(WORK_AHCIEVE)', '전문가형(WORK_SPECIAL)', '논리형(WORK_DATADRIVEN)',
#        '일중심사고형(WORK_WORKERHOLIC)', '협력형(WORK_COWORK)', '과정주의형(WORK_PROCESS)',
#        '몰입형(WORK_ABSORB)', '마당발형(WORK_POPULAR)', '모사형(WORK_RELATE)'],
#       dtype='object')

# %%
df['연령'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 303    False
# 304    False
# 305    False
# 306    False
# 307     True
# Name: 연령, Length: 308, dtype: bool

# %%
df['연령'].value_counts()
# Out:
# 연령
# 30.0    139
# 40.0     77
# 50.0     55
# 20.0     25
# 60.0     11
# Name: count, dtype: int64

# %%
work_columns = [col for col in df.columns if "(WORK_" in col]
print(len(work_columns))
print(work_columns)
# Out:
# 36
# ['목표지향형(WORK_GOAL)', '혁신형(WORK_INNOVATE)', '도전형(WORK_CHALLENGE)', '역할중심형(WORK_RULEBASE)', '오만형(WORK_LEAD)', '솔선수범형(WORK_INITIATIVE)', '자기확신형(WORK_CONFIDENCE)', '유니크형(WORK_UNIQUE)', '부정형(WORK_DEFENCE)', '책임형(WORK_RESPONSE)', '투쟁형(WORK_STRUGGLE)', '스피드형(WORK_SPEED)', '창조형(WORK_CREAT)', '윤리형(WORK_HONEST)', '열정형(WORK_PASSION)', '조력자형(WORK_HELP)', '긍정형(WORK_POSITIVE)', '신뢰형(WORK_TRUST)', '끈기형(WORK_ENDURANCE)', '과몰입형(WORK_PRIDE)', '스마트형(WORK_SMART)', '방관형(WORK_LIMIT)', '분석형(WORK_ANALYSIS)', '열린사고형(WORK_OPEN)', '겸손형(WORK_MODESTY)', '촉진자형(WORK_FACILITATE)', '직관형(WORK_INTUITION)', '성취형(WORK_AHCIEVE)', '전문가형(WORK_SPECIAL)', '논리형(WORK_DATADRIVEN)', '일중심사고형(WORK_WORKERHOLIC)', '협력형(WORK_COWORK)', '과정주의형(WORK_PROCESS)', '몰입형(WORK_ABSORB)', '마당발형(WORK_POPULAR)', '모사형(WORK_RELATE)']

# %%
df['연령대'] = df['연령'].apply(lambda x: f"{int(x//10*10)}대" if pd.notnull(x) else "알수없음")
grouped_stats = df.groupby('연령대')[work_columns].agg(['mean', 'std'])
print(grouped_stats)
# Out:
#      목표지향형(WORK_GOAL)           혁신형(WORK_INNOVATE)            \
#                  mean       std               mean       std
# 연령대
# 20대          2.563600  0.584907           1.477600  1.407786
# 30대          2.600216  0.796337           1.994604  1.341069
# 40대          2.732987  0.696117           2.397013  1.193113
# 50대          2.757091  0.749117           2.559091  1.393972
# 60대          2.700909  0.660658           1.991818  1.111871
# 알수없음              NaN       NaN                NaN       NaN
#
#      도전형(WORK_CHALLENGE)           역할중심형(WORK_RULEBASE)            \
#                     mean       std                 mean       std
# 연령대
# 20대             2.159200  0.877862             2.534000  0.693560
# 30대             2.501439  0.877266             2.523381  0.744742
# 40대             2.794675  0.882286             2.367273  0.724394
# 50대             3.176545  0.827346             2.223636  0.645030
# 60대             3.325455  0.625833             2.454545  0.733531
# 알수없음                 NaN       NaN                  NaN       NaN
#
#      오만형(WORK_LEAD)            ... 협력형(WORK_COWORK)            \
#                mean       std  ...             mean       std
# 연령대                            ...
# 20대        1.329200  0.970094  ...         3.262400  0.658858
# 30대        1.510288  0.890228  ...         3.260072  0.797722
# 40대        1.651688  1.008663  ...         3.211688  0.824947
# 50대        1.708000  0.995606  ...         3.336364  0.844743
# 60대        1.720000  1.117238  ...         2.971818  0.623920
# 알수없음            NaN       NaN  ...              NaN       NaN
#
#      과정주의형(WORK_PROCESS)           몰입형(WORK_ABSORB)            \
#                     mean       std             mean       std
# 연령대
# 20대             2.570000  0.762124         2.546400  0.738263
# 30대             2.575540  0.840901         2.596978  0.886049
# 40대             2.610390  0.774271         2.493636  0.744764
# 50대             2.686364  0.792351         2.435636  0.849138
# 60대             2.727273  0.737009         2.727273  0.662798
# 알수없음                 NaN       NaN              NaN       NaN
#
#      마당발형(WORK_POPULAR)           모사형(WORK_RELATE)
#                    mean       std             mean       std
# 연령대
# 20대            2.440000  1.157584         1.960000  0.644205
# 30대            2.309353  1.339743         2.039568  0.794147
# 40대            2.350649  1.305517         2.012987  0.884717
# 50대            2.581818  1.356615         2.100000  0.754002
# 60대            1.818182  0.981650         2.045455  0.850134
# 알수없음                NaN       NaN              NaN       NaN
#
# [6 rows x 72 columns]

# %%
first_work_col = work_columns[0]

plt.figure(figsize=(10, 6))
for age_group in df['연령대'].unique():
    sns.kdeplot(data=df[df['연령대'] == age_group][first_work_col], label=f"{age_group}")

plt.title(f"{first_work_col} 연령대별 분포(KDE)")
plt.xlabel(first_work_col)
plt.ylabel("Density")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1669617/1466427145.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df[df['연령대'] == age_group][first_work_col], label=f"{age_group}")

# %%
plt.figure(figsize=(10, 6))
x_vals = np.linspace(df[first_work_col].min(), df[first_work_col].max(), 100)
for age_group in df['연령대'].unique():
    mean_val = grouped_stats.loc[age_group, (first_work_col, 'mean')]
    std_val = grouped_stats.loc[age_group, (first_work_col, 'std')]
    if pd.notna(mean_val) and pd.notna(std_val) and std_val != 0:
        y_vals = norm.pdf(x_vals, mean_val, std_val)
        plt.plot(x_vals, y_vals, label=f"{age_group} (Mean={mean_val:.2f}, Std={std_val:.2f})")

plt.title(f"{first_work_col} 연령대별 정규분포 가정 PDF")
plt.xlabel(first_work_col)
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
df['연령대'] = df['연령'].apply(lambda x: f"{int(x//10*10)}대" if pd.notnull(x) else "알수없음")

count_table = pd.crosstab(df['연령대'], df['본사/현업'])
ratio_table = count_table.div(count_table.sum(axis=1), axis=0)

plt.figure(figsize=(10, 6))
ratio_table.plot(kind='bar', stacked=True)
plt.title("연령대별 본사/현업 비율")
plt.xlabel("연령대")
plt.ylabel("비율")
plt.legend(title="본사/현업", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
count_table = df['본사/현업'].value_counts()

plt.figure(figsize=(6, 6))
count_table.plot(kind='pie', autopct='%.1f%%', startangle=90)
plt.title("전체 본사/현업 비율")
plt.ylabel("")
plt.show()

# %%
# Filter the 근속년수 column
tenure_data = df['근속년수']

# Plot the distribution of 근속년수
plt.figure(figsize=(10, 6))
plt.hist(tenure_data, bins=20, alpha=0.75, edgecolor='k')
plt.title('근속년수 분포', fontsize=14)
plt.xlabel('근속년수 (년)', fontsize=12)
plt.ylabel('빈도', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
